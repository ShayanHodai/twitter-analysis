# %% [markdown]
# ### The program is running on a cloud server and each day it automatically runs at 00:00. The Ip of the server is 20.81.153.226

# %%
'''
Author: Shayan Hodai shayan.hodai@gmail.com
Date: 4 March 2023
Purpose: Scrape tweets from choosen accounts, do sentiment analysis on threads and replies and build REST API with 6 endpoints on a cloud server to serve requests
'''
import scrapper
import sentiment
import api
import snscrape.modules.twitter as sntwitter
import numpy as np
import pandas as pd
import re
from transformers import pipeline
import warnings
warnings.filterwarnings("ignore")

# %%
accounts = ['elonmusk', 'ylecun', 'BarackObama'] #accounts which we want to scrape tweets from

# %% [markdown]
# ### Step 1. Scrape tweets

# %%
tweets_df = scrapper.tweets(accounts)

# %%
tweets_df.head()
# Out:
#                     Id                      Date  Username  \
# 0  1633985037375877120 2023-03-10 00:16:05+00:00  elonmusk
# 1  1633963976945008643 2023-03-09 22:52:24+00:00  elonmusk
# 2  1633876365651918848 2023-03-09 17:04:16+00:00  elonmusk
# 3  1633767312565125120 2023-03-09 09:50:55+00:00  elonmusk
# 4  1633597893860020224 2023-03-08 22:37:43+00:00  elonmusk
#
#                                                Tweet
# 0  To be alerted about new tweets from any accoun...
# 1                            https://t.co/IYlRo3fd59
# 2                                         Concerning
# 3  Sometimes we miss here at Starbase https://t.c...
# 4                        🤬 😂 https://t.co/zPXgj1cN5v

# %%
threads_df = scrapper.threads(accounts, tweets_df)

# %%
threads_df.head()
# Out:
#                     Id                                             Thread
# 0  1632681788941139972  [(real article from organization calling itsel...
# 1  1631725881378082816  [Stage 1 to stage 2 mass ratio is too high on ...
# 2  1631055228089794560  [Detailed whitepaper with calculations &amp; a...
# 3  1629901954234105857  [But, all things considered with regard to AGI...
# 4  1629633384338149378   [https://t.co/nBq4YHkaK4, Disturbingly accurate]

# %%
replies_df = scrapper.replies(accounts, tweets_df)

# %%
replies_df.head()
# Out:
#                     Id                                       Replied_User  \
# 0  1633985037375877120  [DaoKwonDo, ignacy_aw, ahmeedy199, krishnaeyee...
# 1  1633963976945008643  [Luckyjs37, CryptoVam, deepfilip, I_G_DEFI, op...
# 2  1633876365651918848  [NovakGOATovic, KrisPersson, JasonFyk, ImNotTh...
# 3  1633767312565125120  [Michell81918935, GayRepublicSwag, Cooper_Hime...
# 4  1633597893860020224  [ethan_harsell, Gritty20202, SanteSuzie, willi...
#
#                                                Reply
# 0  [@elonmusk Dude that’s what I told people last...
# 1  [@elonmusk $BBIG 👨‍🚀, @elonmusk Sauron, is dat...
# 2  [@elonmusk Any thoughts on how the vaccine hyp...
# 3  [@elonmusk Should there be a sprinkler on righ...
# 4  [@elonmusk Yay pizza party https://t.co/yZ1mSP...

# %%
replies_df = scrapper.rm_dup(threads_df['Thread'], replies_df)

# %%
replies_df.head()
# Out:
#                     Id                                       Replied_User  \
# 0  1633985037375877120  [DaoKwonDo, ignacy_aw, ahmeedy199, krishnaeyee...
# 1  1633963976945008643  [Luckyjs37, CryptoVam, deepfilip, I_G_DEFI, op...
# 2  1633876365651918848  [NovakGOATovic, KrisPersson, JasonFyk, ImNotTh...
# 3  1633767312565125120  [Michell81918935, GayRepublicSwag, Cooper_Hime...
# 4  1633597893860020224  [ethan_harsell, Gritty20202, SanteSuzie, willi...
#
#                                                Reply
# 0  [@elonmusk Dude that’s what I told people last...
# 1  [@elonmusk $BBIG 👨‍🚀, @elonmusk Sauron, is dat...
# 2  [@elonmusk Any thoughts on how the vaccine hyp...
# 3  [@elonmusk Should there be a sprinkler on righ...
# 4  [@elonmusk Yay pizza party https://t.co/yZ1mSP...

# %%
all_tweets = scrapper.merge_dfs(tweets_df, threads_df, replies_df)

# %%
all_tweets.head()
# Out:
#                     Id                      Date  Username  \
# 0  1633985037375877120 2023-03-10 00:16:05+00:00  elonmusk
# 1  1633963976945008643 2023-03-09 22:52:24+00:00  elonmusk
# 2  1633876365651918848 2023-03-09 17:04:16+00:00  elonmusk
# 3  1633767312565125120 2023-03-09 09:50:55+00:00  elonmusk
# 4  1633597893860020224 2023-03-08 22:37:43+00:00  elonmusk
#
#                                               Thread  \
# 0  [To be alerted about new tweets from any accou...
# 1                          [https://t.co/IYlRo3fd59]
# 2                                       [Concerning]
# 3  [Sometimes we miss here at Starbase https://t....
# 4                      [🤬 😂 https://t.co/zPXgj1cN5v]
#
#                                         Replied_User  \
# 0  [DaoKwonDo, ignacy_aw, ahmeedy199, krishnaeyee...
# 1  [Luckyjs37, CryptoVam, deepfilip, I_G_DEFI, op...
# 2  [NovakGOATovic, KrisPersson, JasonFyk, ImNotTh...
# 3  [Michell81918935, GayRepublicSwag, Cooper_Hime...
# 4  [ethan_harsell, Gritty20202, SanteSuzie, willi...
#
#                                                Reply
# 0  [@elonmusk Dude that’s what I told people last...
# 1  [@elonmusk $BBIG 👨‍🚀, @elonmusk Sauron, is dat...
# 2  [@elonmusk Any thoughts on how the vaccine hyp...
# 3  [@elonmusk Should there be a sprinkler on righ...
# 4  [@elonmusk Yay pizza party https://t.co/yZ1mSP...

# %%
all_tweets = scrapper.preprocess(all_tweets)

# %%
all_tweets.head()
# Out:
#                     Id                       Date   Account  \
# 0  1633985037375877120  2023-03-10 00:16:05+00:00  elonmusk
# 1  1633876365651918848  2023-03-09 17:04:16+00:00  elonmusk
# 2  1633767312565125120  2023-03-09 09:50:55+00:00  elonmusk
# 3  1633597893860020224  2023-03-08 22:37:43+00:00  elonmusk
# 4  1633587625092169730  2023-03-08 21:56:55+00:00  elonmusk
#
#                                               Thread  \
# 0  [to be alerted about new tweets from any accou...
# 1                                       [concerning]
# 2              [sometimes we miss here at starbase ]
# 3                                             [🤬 😂 ]
# 4    [&lt;insert cartridge&gt; &lt;run program&gt; ]
#
#                                             Audience  \
# 0  [DaoKwonDo, ignacy_aw, ahmeedy199, krishnaeyee...
# 1  [NovakGOATovic, KrisPersson, JasonFyk, ImNotTh...
# 2  [Michell81918935, GayRepublicSwag, Cooper_Hime...
# 3  [ethan_harsell, Gritty20202, SanteSuzie, willi...
# 4  [reggiewatts, mrfarhadiii, lyssasphere, _Bongz...
#
#                                                Reply
# 0  [ dude thats what i told people last week,  co...
# 1  [ any thoughts on how the vaccine hypocrisy ha...
# 2  [ should there be a sprinkler on right as well...
# 3  [ yay pizza party ,  shitting on your entire s...
# 4  [ it should read elon musk has become the enem...

# %% [markdown]
# ### Step 2. Sentiment analysis using transforms from hugging face API

# %%
tweets_and_sentiments = sentiment.do(all_tweets)
# Out:
# Downloading (…)lve/main/config.json: 100%|██████████| 949/949 [00:00<00:00, 159kB/s]
# Downloading pytorch_model.bin: 100%|██████████| 540M/540M [00:05<00:00, 97.9MB/s]
# Downloading (…)okenizer_config.json: 100%|██████████| 338/338 [00:00<00:00, 37.7kB/s]
# Downloading (…)solve/main/vocab.txt: 100%|██████████| 843k/843k [00:00<00:00, 8.19MB/s]
# Downloading (…)solve/main/bpe.codes: 100%|██████████| 1.08M/1.08M [00:00<00:00, 10.2MB/s]
# Downloading (…)in/added_tokens.json: 100%|██████████| 22.0/22.0 [00:00<00:00, 2.21kB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 167/167 [00:00<00:00, 18.6kB/s]

# %%
tweets_and_sentiments.head()
# Out:
#                     Id                       Date   Account  \
# 0  1633985037375877120  2023-03-10 00:16:05+00:00  elonmusk
# 1  1633876365651918848  2023-03-09 17:04:16+00:00  elonmusk
# 2  1633767312565125120  2023-03-09 09:50:55+00:00  elonmusk
# 3  1633597893860020224  2023-03-08 22:37:43+00:00  elonmusk
# 4  1633587625092169730  2023-03-08 21:56:55+00:00  elonmusk
#
#                                               Thread  \
# 0  [to be alerted about new tweets from any accou...
# 1                                       [concerning]
# 2              [sometimes we miss here at starbase ]
# 3                                             [🤬 😂 ]
# 4    [&lt;insert cartridge&gt; &lt;run program&gt; ]
#
#                                             Audience  \
# 0  [DaoKwonDo, ignacy_aw, ahmeedy199, krishnaeyee...
# 1  [NovakGOATovic, KrisPersson, JasonFyk, ImNotTh...
# 2  [Michell81918935, GayRepublicSwag, Cooper_Hime...
# 3  [ethan_harsell, Gritty20202, SanteSuzie, willi...
# 4  [reggiewatts, mrfarhadiii, lyssasphere, _Bongz...
#
#                                                Reply  \
# 0  [ dude thats what i told people last week,  co...
# 1  [ any thoughts on how the vaccine hypocrisy ha...
# 2  [ should there be a sprinkler on right as well...
# 3  [ yay pizza party ,  shitting on your entire s...
# 4  [ it should read elon musk has become the enem...
#
#                                 Thread_Sentiment  \
# 0  {'NEG': '0.00', 'NEU': '0.95', 'POS': '0.00'}
# 1  {'NEG': '0.00', 'NEU': '0.90', 'POS': '0.00'}
# 2  {'NEG': '0.00', 'NEU': '0.71', 'POS': '0.00'}
# 3  {'NEG': '0.00', 'NEU': '0.91', 'POS': '0.00'}
# 4  {'NEG': '0.00', 'NEU': '0.97', 'POS': '0.00'}
#
#                                  Reply_Sentiment
# 0  {'NEG': '0.20', 'NEU': '0.49', 'POS': '0.14'}
# 1  {'NEG': '0.51', 'NEU': '0.26', 'POS': '0.07'}
# 2  {'NEG': '0.12', 'NEU': '0.49', 'POS': '0.24'}
# 3  {'NEG': '0.23', 'NEU': '0.47', 'POS': '0.15'}
# 4  {'NEG': '0.37', 'NEU': '0.37', 'POS': '0.11'}

# %% [markdown]
# ### Step3. Initialize Rest API with 6 endpoints using flask

# %%
api.initial(tweets_and_sentiments)

# %% [markdown]
# ### Done!
#
# http://127.0.0.1:5000/accounts -> returns json file of the accounts
#
# http://127.0.0.1:5000/threads -> returns json file of the threads
#
# http://127.0.0.1:5000/replies -> returns json file of the replies
#
# http://127.0.0.1:5000/audience -> returns json file of the audince (the accounts who replied to the tweet)
#
# http://127.0.0.1:5000/th -> returns json file of the replies
#
# http://127.0.0.1:5000/threads_sentiment -> returns json file of the threads sentiment
#
# http://127.0.0.1:5000/replies_sentiment -> returns json file of the replies sentiment
#
# or either have access from your local machine through my virtual machine on a cloud server 20.81.153.226:5000/same endpoints as above
